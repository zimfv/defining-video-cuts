# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from mytools import Video, get_cuts

# %% [markdown]
# # Video 0

# %%
video_filename = 'videos/0.mp4'
timeline_filename = 'timelines/0.kdenlive'

# %%
video = Video(video_filename)

print(f'video.length = {video.length}\nvideo.width = {video.width}\nvideo.height = {video.height}\n')

fps = video.get_fps()
print(f'video FPS = {fps}')

frame_index = 221
frame = video.get_frame(frame_index)

print(f'frame_index = {frame_index}')
print(f'frame.shape = {frame.shape}\nframe.dtype = {frame.dtype}')

plt.imshow(frame)
# Out:
# video.length = 5875
# video.width = 640
# video.height = 360
#
# video FPS = 25.0
# frame_index = 221
# frame.shape = (360, 640, 3)
# frame.dtype = uint8

# %%
cuts = get_cuts(timeline_filename, fps=fps)

# %%
diff = [abs(matrix[1] - matrix[0]).sum() for matrix in tqdm(video.generate_matrices(2), total=video.length-2)]
# Out:
#   0%|          | 0/5873 [00:00<?, ?it/s]

# %%
# Normalize values, deviding them by max possible
diff = np.array(diff) / (3*255*video.width*video.height)
diff.shape
# Out:
# (5873,)

# %%
plt.figure(figsize=(18, 6))

plt.plot(diff)
plt.title(f'{video_filename}\nRGB gradient')
plt.xticks(cuts, rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # Video 1

# %%
video_filename = 'videos/1.mp4'
timeline_filename = 'timelines/1.kdenlive'

# %%
video = Video(video_filename)

print(f'video.length = {video.length}\nvideo.width = {video.width}\nvideo.height = {video.height}\n')

fps = video.get_fps()
print(f'video FPS = {fps}')

frame_index = 221
frame = video.get_frame(frame_index)

print(f'frame_index = {frame_index}')
print(f'frame.shape = {frame.shape}\nframe.dtype = {frame.dtype}')

plt.imshow(frame)
# Out:
# video.length = 5750
# video.width = 640
# video.height = 360
#
# video FPS = 23.976023976023978
# frame_index = 221
# frame.shape = (360, 640, 3)
# frame.dtype = uint8

# %%
cuts = get_cuts(timeline_filename, fps=fps)

# %%
diff = [abs(matrix[1] - matrix[0]).sum() for matrix in tqdm(video.generate_matrices(2), total=video.length-2)]
# Out:
#   0%|          | 0/5748 [00:00<?, ?it/s]

# %%
# Normalize values, deviding them by max possible
diff = np.array(diff) / (3*255*video.width*video.height)
diff.shape
# Out:
# (5748,)

# %%
plt.figure(figsize=(18, 6))

plt.plot(diff)
plt.title(f'{video_filename}\nRGB gradient')
plt.xticks(cuts, rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # Video 2

# %%
video_filename = 'videos/2.mp4'
timeline_filename = 'timelines/2.kdenlive'

# %%
video = Video(video_filename)

print(f'video.length = {video.length}\nvideo.width = {video.width}\nvideo.height = {video.height}\n')

fps = video.get_fps()
print(f'video FPS = {fps}')

frame_index = 221
frame = video.get_frame(frame_index)

print(f'frame_index = {frame_index}')
print(f'frame.shape = {frame.shape}\nframe.dtype = {frame.dtype}')

plt.imshow(frame)
# Out:
# video.length = 6061
# video.width = 640
# video.height = 360
#
# video FPS = 23.976023976023978
# frame_index = 221
# frame.shape = (360, 640, 3)
# frame.dtype = uint8

# %%
cuts = get_cuts(timeline_filename, fps=fps)

# %%
diff = [abs(matrix[1] - matrix[0]).sum() for matrix in tqdm(video.generate_matrices(2), total=video.length-2)]
# Out:
#   0%|          | 0/6059 [00:00<?, ?it/s]

# %%
# Normalize values, deviding them by max possible
diff = np.array(diff) / (3*255*video.width*video.height)
diff.shape
# Out:
# (6059,)

# %%
plt.figure(figsize=(18, 6))

plt.plot(diff)
plt.title(f'{video_filename}\nRGB gradient')
plt.xticks(cuts, rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # Video 3

# %%
video_filename = 'videos/3.mp4'
timeline_filename = 'timelines/3.kdenlive'

# %%
video = Video(video_filename)

print(f'video.length = {video.length}\nvideo.width = {video.width}\nvideo.height = {video.height}\n')

fps = video.get_fps()
print(f'video FPS = {fps}')

frame_index = 221
frame = video.get_frame(frame_index)

print(f'frame_index = {frame_index}')
print(f'frame.shape = {frame.shape}\nframe.dtype = {frame.dtype}')

plt.imshow(frame)
# Out:
# video.length = 3961
# video.width = 480
# video.height = 360
#
# video FPS = 25.0
# frame_index = 221
# frame.shape = (360, 480, 3)
# frame.dtype = uint8

# %%
cuts = get_cuts(timeline_filename, fps=fps)

# %%
diff = [abs(matrix[1] - matrix[0]).sum() for matrix in tqdm(video.generate_matrices(2), total=video.length-2)]
# Out:
#   0%|          | 0/3959 [00:00<?, ?it/s]

# %%
# Normalize values, deviding them by max possible
diff = np.array(diff) / (3*255*video.width*video.height)
diff.shape
# Out:
# (3959,)

# %%
plt.figure(figsize=(18, 6))

plt.plot(diff)
plt.title(f'{video_filename}\nRGB gradient')
plt.xticks(cuts, rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # Video 4

# %%
video_filename = 'videos/4.mp4'
timeline_filename = 'timelines/4.kdenlive'

# %%
video = Video(video_filename)

print(f'video.length = {video.length}\nvideo.width = {video.width}\nvideo.height = {video.height}\n')

fps = video.get_fps()
print(f'video FPS = {fps}')

frame_index = 221
frame = video.get_frame(frame_index)

print(f'frame_index = {frame_index}')
print(f'frame.shape = {frame.shape}\nframe.dtype = {frame.dtype}')

plt.imshow(frame)
# Out:
# video.length = 5249
# video.width = 640
# video.height = 274
#
# video FPS = 23.976023976023978
# frame_index = 221
# frame.shape = (274, 640, 3)
# frame.dtype = uint8

# %%
cuts = get_cuts(timeline_filename, fps=fps)

# %%
diff = [abs(matrix[1] - matrix[0]).sum() for matrix in tqdm(video.generate_matrices(2), total=video.length-2)]
# Out:
#   0%|          | 0/5247 [00:00<?, ?it/s]

# %%
# Normalize values, deviding them by max possible
diff = np.array(diff) / (3*255*video.width*video.height)
diff.shape
# Out:
# (5247,)

# %%
plt.figure(figsize=(18, 6))

plt.plot(diff)
plt.title(f'{video_filename}\nRGB gradient')
plt.xticks(cuts, rotation=90)
plt.grid()
plt.show()
